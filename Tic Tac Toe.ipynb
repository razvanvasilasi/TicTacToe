# %%
from IPython.display import clear_output

def display_board(board):
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('-----------')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('-----------')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    
def player_marker():
    marker=''
    while marker!='X' and marker !='O':
        marker=input('Player One please choose your marker (X or O): ').upper()
        if marker == 'X':
            return ('X','O')
        else:
            return ('O','X')

def place_marker(board,marker,position):
    board[position]=marker

def win_check(board,mark):
    return ((board[1]==mark and board[2]==mark and board[3]==mark) or
    (board[4]==mark and board[5]==mark and board[6]==mark) or
    ((board[7]==mark and board[8]==mark and board[9])==mark) or
    ((board[7]==mark and board[4]==mark and board[1])==mark) or
    ((board[8]==mark and board[5]==mark and board[2])==mark) or
    ((board[9]==mark and board[6]==mark and board[3])==mark) or
    ((board[1]==mark and board[5]==mark and board[9])==mark) or
    ((board[7]==mark and board[5]==mark and board[3])==mark))

def choose_first():
    from random import randint
    x=randint(1,2)
    return x
    
def space_check(board,position):
    if board[position] not in ('X','O'):
        return True
    else:
        return False
    
def full_board_check(board):
    for i in range(1,9):
        if board[i] not in ('X','O'):
            return False
    return True
        
        
def player_choise(board):
    choise=''
    while choise not in range(1,9):
        choise=input('Please pick a position between 1 and 9: ')
        if space_check(board,int(choise))==True:
            return int(choise)
        else:
            print('Position Taken! Please choose again!')
            choise=''

def replay():
    replay_choise=''
    while replay_choise not in ('Y','N'):
        replay_choise=input('Do you want to play again? (Y or N):').upper()
        if replay_choise=='Y':
            return True
        else:
            return False

# %%
#GAME LOGIC
print('Wellcome to Tic Tac Toe!')
board=[' ']*10
display_board(board)
play = True
while play:
    board = [' ']*10
    Player1, Player2 = player_marker()
    turn = choose_first()
    game_on=True
    while game_on:
        if turn == 1:
            clear_output()
            display_board(board)
            print("Player1's Turn!")
            position = player_choise(board)
            if not full_board_check(board):
                place_marker(board, Player1, position)
                clear_output()
                display_board(board)
            else:
                print("It's a draw!")
                game_on = False
            if win_check(board, Player1):
                print('Congrats! Player1 has wo the Game!')
                game_on=False
            else:
                turn = 2
        else:
            clear_output()
            display_board(board)
            print("Player2's Turn!")
            position = player_choise(board)
            if not full_board_check(board):
                place_marker(board, Player2, position)
                clear_output()
                display_board(board)
            else:
                print("It's a draw!")
                game_on = False
            if win_check(board, Player2):
                print('Congrats! Player2 has won the Game!')
                game_on = False
            else:
                turn = 1
    game_on = replay()
    if game_on == False:
        play = False
        print('Thanks for playing!')
    else:
        play = True
